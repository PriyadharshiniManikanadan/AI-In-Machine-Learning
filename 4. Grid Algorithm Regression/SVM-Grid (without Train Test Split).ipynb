# %% [markdown]
# ## SVM-Grid (Without Train Test Split)

# %%
import pandas as pd

# %% [markdown]
# ### Data collection

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# ### Data preprocessing

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %% [markdown]
# ### Input Output split

# %%
indep = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes' ]]
dep = dataset[['charges']]

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler
SC = StandardScaler()
indep = SC.fit_transform(indep)

# %%
indep
# Out:
# array([[-1.43876426, -0.45332   , -0.90861367, -1.0105187 ,  1.97058663],
#        [-1.50996545,  0.5096211 , -0.07876719,  0.98959079, -0.5074631 ],
#        [-0.79795355,  0.38330685,  1.58092576,  0.98959079, -0.5074631 ],
#        ...,
#        [-1.50996545,  1.0148781 , -0.90861367, -1.0105187 , -0.5074631 ],
#        [-1.29636188, -0.79781341, -0.90861367, -1.0105187 , -0.5074631 ],
#        [ 1.55168573, -0.26138796, -0.90861367, -1.0105187 ,  1.97058663]])

# %% [markdown]
# ### Model Creation Through GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

params_grid = {'kernel':['linear','rbf','poly','sigmoid'],
              'C' : [1,10,100,1000,2000,3000], 
              'gamma' : ['scale','auto']}

grid = GridSearchCV(SVR(), params_grid, refit = True, verbose = 3, n_jobs= -1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100, 1000, 2000, 3000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=3)

# %%
# print the best parameter after tuning
result = grid.cv_results_

grid_predictions = grid.predict(indep)

from sklearn.metrics import r2_score
R2_Score = r2_score(dep, grid_predictions)

# print(grid.best_params_)
print("Best parameter of SVM-Grid {}:",format(grid.best_params_),R2_Score)
# Out:
# Best parameter of SVM-Grid {}: {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'} 0.8382747818757239

# %%
Total = pd.DataFrame(result)
Total
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.118108      0.001078         0.018925        0.001914       1
# 1        0.167484      0.007945         0.086989        0.003095       1
# 2        0.126277      0.004103         0.021199        0.002881       1
# 3        0.171318      0.007278         0.030875        0.001370       1
# 4        0.119072      0.006373         0.018327        0.001379       1
# 5        0.152901      0.006158         0.083765        0.004942       1
# 6        0.117920      0.004383         0.021730        0.001652       1
# 7        0.172651      0.003991         0.033301        0.001524       1
# 8        0.125374      0.004752         0.019003        0.001047      10
# 9        0.153967      0.006352         0.091932        0.008239      10
# 10       0.121362      0.004456         0.021441        0.001157      10
# 11       0.170178      0.007211         0.032562        0.001131      10
# 12       0.118456      0.004464         0.018226        0.001207      10
# 13       0.156897      0.008459         0.089905        0.006079      10
# 14       0.122056      0.007320         0.020248        0.000915      10
# 15       0.173389      0.003094         0.041982        0.006488      10
# 16       0.150635      0.011628         0.018113        0.001174     100
# 17       0.171782      0.010269         0.102155        0.006310     100
# 18       0.172888      0.007760         0.025711        0.004920     100
# 19       0.223031      0.020740         0.034276        0.003293     100
# 20       0.142445      0.012965         0.019653        0.002295     100
# 21       0.164569      0.008318         0.085954        0.004574     100
# 22       0.147976      0.015949         0.024573        0.006342     100
# 23       0.218583      0.009694         0.035529        0.002893     100
# 24       0.186324      0.012441         0.019866        0.001221    1000
# 25       0.192167      0.011734         0.087524        0.005178    1000
# 26       0.216933      0.026471         0.022462        0.002490    1000
# 27       0.213733      0.009629         0.035118        0.003681    1000
# 28       0.185693      0.006410         0.023095        0.002192    1000
# 29       0.199903      0.009897         0.092099        0.007475    1000
# 30       0.226568      0.033525         0.022877        0.002409    1000
# 31       0.206748      0.012744         0.034403        0.002732    1000
# 32       0.236508      0.004829         0.019556        0.001380    2000
# 33       0.204476      0.006657         0.083542        0.002527    2000
# 34       0.276827      0.034651         0.021439        0.001391    2000
# 35       0.205028      0.010686         0.033326        0.002114    2000
# 36       0.213275      0.012588         0.018309        0.001189    2000
# 37       0.198117      0.004737         0.082013        0.004742    2000
# 38       0.296211      0.096224         0.020872        0.001466    2000
# 39       0.193687      0.007155         0.032572        0.002264    2000
# 40       0.253898      0.013880         0.018993        0.001621    3000
# 41       0.230195      0.018693         0.086759        0.003642    3000
# 42       0.441495      0.091664         0.023455        0.003084    3000
# 43       0.236496      0.027151         0.033725        0.001039    3000
# 44       0.262461      0.018207         0.024241        0.003222    3000
# 45       0.261835      0.019273         0.096033        0.004878    3000
# 46       0.561061      0.200857         0.017966        0.004687    3000
# 47       0.212592      0.028895         0.030387        0.003585    3000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale          rbf
# 2        scale         poly
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto          rbf
# 6         auto         poly
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale          rbf
# 10       scale         poly
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto          rbf
# 14        auto         poly
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale          rbf
# 18       scale         poly
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto          rbf
# 22        auto         poly
# 23        auto      sigmoid
# 24       scale       linear
# 25       scale          rbf
# 26       scale         poly
# 27       scale      sigmoid
# 28        auto       linear
# 29        auto          rbf
# 30        auto         poly
# 31        auto      sigmoid
# 32       scale       linear
# 33       scale          rbf
# 34       scale         poly
# 35       scale      sigmoid
# 36        auto       linear
# 37        auto          rbf
# 38        auto         poly
# 39        auto      sigmoid
# 40       scale       linear
# 41       scale          rbf
# 42       scale         poly
# 43       scale      sigmoid
# 44        auto       linear
# 45        auto          rbf
# 46        auto         poly
# 47        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}          -0.025629
# 1         {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}          -0.108985
# 2        {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}          -0.099348
# 3     {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.100605
# 4       {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}          -0.025629
# 5          {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}          -0.108974
# 6         {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}          -0.099561
# 7      {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.100652
# 8     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.487873
# 9        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.050517
# 10      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.039041
# 11   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.029716
# 12     {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.487873
# 13        {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.050402
# 14       {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.037227
# 15    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.029301
# 16   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.641464
# 17      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.360068
# 18     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.654011
# 19  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.527367
# 20    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.641464
# 21       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.360724
# 22      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.650669
# 23   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.531459
# 24  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.672679
# 25     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.833330
# 26    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.848927
# 27  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.161027
# 28   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.672679
# 29      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.833468
# 30     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.848655
# 31  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.170988
# 32  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.671545
# 33     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.863070
# 34    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.851782
# 35  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.075530
# 36   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.671545
# 37      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.863090
# 38     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.851467
# 39  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.377095
# 40  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.668269
# 41     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.870230
# 42    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.852350
# 43  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -3.433129
# 44   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.668269
# 45      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.870252
# 46     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.852383
# 47  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -3.510085
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.011630           0.007866          -0.014337
# 1           -0.106259          -0.075060          -0.099683
# 2           -0.096181          -0.066486          -0.091099
# 3           -0.094790          -0.066371          -0.091028
# 4           -0.011630           0.007866          -0.014337
# 5           -0.106280          -0.075075          -0.099676
# 6           -0.095837          -0.066222          -0.091226
# 7           -0.094705          -0.066310          -0.091058
# 8            0.472341           0.485102           0.475835
# 9           -0.045096          -0.016601          -0.041415
# 10           0.040111           0.063362           0.042506
# 11           0.042770           0.059852           0.040918
# 12           0.472341           0.485102           0.475835
# 13          -0.045276          -0.016737          -0.041345
# 14           0.042884           0.065672           0.041406
# 15           0.043379           0.060402           0.040689
# 16           0.601994           0.627339           0.628877
# 17           0.348158           0.362312           0.343255
# 18           0.612976           0.636708           0.617573
# 19           0.490754           0.520064           0.511215
# 20           0.601994           0.627339           0.628877
# 21           0.347206           0.361437           0.343682
# 22           0.616836           0.642137           0.615462
# 23           0.492180           0.518726           0.511646
# 24           0.620927           0.730011           0.632260
# 25           0.754986           0.802746           0.777131
# 26           0.774567           0.868177           0.805541
# 27           0.099347           0.157690           0.184345
# 28           0.620927           0.730011           0.632260
# 29           0.754793           0.802307           0.777257
# 30           0.774485           0.868188           0.805521
# 31          -0.021689           0.135578           0.120185
# 32           0.618499           0.728708           0.627927
# 33           0.775993           0.848544           0.801377
# 34           0.774049           0.868717           0.807810
# 35          -1.732497          -1.358992          -1.172710
# 36           0.618499           0.728708           0.627927
# 37           0.775949           0.848369           0.801411
# 38           0.773953           0.868926           0.807826
# 39          -1.487236          -1.402559          -1.330143
# 40           0.618040           0.728704           0.627698
# 41           0.781912           0.855341           0.806008
# 42           0.773058           0.868576           0.806808
# 43          -4.040316          -3.681947          -3.469604
# 44           0.618040           0.728704           0.627698
# 45           0.781886           0.855146           0.806056
# 46           0.773067           0.868612           0.806641
# 47          -4.162603          -3.787697          -3.774905
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.027381        -0.014222        0.012632               35
# 1           -0.100792        -0.098156        0.012047               43
# 2           -0.092252        -0.089073        0.011666               40
# 3           -0.093774        -0.089314        0.011889               42
# 4           -0.027381        -0.014222        0.012632               35
# 5           -0.100778        -0.098157        0.012041               44
# 6           -0.092426        -0.089054        0.011780               39
# 7           -0.093813        -0.089308        0.011917               41
# 8            0.447692         0.473769        0.014239               25
# 9           -0.048600        -0.040446        0.012321               37
# 10           0.036594         0.044323        0.009707               31
# 11           0.018234         0.038298        0.013912               34
# 12           0.447692         0.473769        0.014239               25
# 13          -0.048491        -0.040450        0.012248               38
# 14           0.034393         0.044316        0.011093               32
# 15           0.017824         0.038319        0.014285               33
# 16           0.596234         0.619182        0.017199               21
# 17           0.332521         0.349263        0.010997               28
# 18           0.608877         0.626029        0.016930               20
# 19           0.485494         0.506979        0.016308               24
# 20           0.596234         0.619182        0.017199               21
# 21           0.333290         0.349268        0.010678               27
# 22           0.606497         0.626320        0.016993               19
# 23           0.486503         0.508103        0.016679               23
# 24           0.691909         0.669557        0.039799               13
# 25           0.783512         0.790341        0.026356               11
# 26           0.808535         0.821149        0.033334                7
# 27           0.077914         0.136065        0.040377               29
# 28           0.691909         0.669557        0.039799               13
# 29           0.783844         0.790334        0.026383               12
# 30           0.808550         0.821080        0.033316                8
# 31           0.099719         0.100956        0.065599               30
# 32           0.691027         0.667541        0.040702               15
# 33           0.812016         0.820200        0.031676                9
# 34           0.815101         0.823492        0.033486                3
# 35          -1.199166        -1.307779        0.231079               45
# 36           0.691027         0.667541        0.040702               15
# 37           0.812077         0.820179        0.031655               10
# 38           0.814939         0.823422        0.033525                4
# 39          -1.162566        -1.351920        0.107552               46
# 40           0.688847         0.666312        0.040560               17
# 41           0.823606         0.827419        0.032113                1
# 42           0.816178         0.823394        0.033884                5
# 43          -3.179970        -3.560993        0.287840               47
# 44           0.688847         0.666312        0.040560               17
# 45           0.823614         0.827391        0.032086                2
# 46           0.816036         0.823348        0.033919                6
# 47          -3.088834        -3.664825        0.355164               48

# %% [markdown]
# ### Get the User Inputs

# %%
Age_input = float(input("Age : "))
Bmi_input = float(input("BMI : "))
Children_input = int(input("Children : "))
SEX_Male_input = int(input("Sex_Male 0 or 1 : "))
Smoker_YES_input = int(input("Smoker_YES 0 or 1 : "))
# Out:
# Age :  32
# BMI :  50
# Children :  2
# Sex_Male 0 or 1 :  1
# Smoker_YES 0 or 1 :  1

# %% [markdown]
# ### Predictions

# %%
Future_predictions = grid.predict([[Age_input,Bmi_input,Children_input,SEX_Male_input,Smoker_YES_input]])
print("Future predictions of Insurance :" , Future_predictions)
# Out:
# Future predictions of Insurance : [17144.08729473]
