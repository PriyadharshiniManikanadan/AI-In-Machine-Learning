# %% [markdown]
# ## DT-Grid (Without Train Test Split)

# %%
import pandas as pd

# %% [markdown]
# ### Data collection

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# ### Data preprocessing

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %% [markdown]
# ### Input Output split

# %%
indep = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes' ]]
dep = dataset[['charges']]

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler
SC = StandardScaler()
indep = SC.fit_transform(indep)

# %%
indep
# Out:
# array([[-1.43876426, -0.45332   , -0.90861367, -1.0105187 ,  1.97058663],
#        [-1.50996545,  0.5096211 , -0.07876719,  0.98959079, -0.5074631 ],
#        [-0.79795355,  0.38330685,  1.58092576,  0.98959079, -0.5074631 ],
#        ...,
#        [-1.50996545,  1.0148781 , -0.90861367, -1.0105187 , -0.5074631 ],
#        [-1.29636188, -0.79781341, -0.90861367, -1.0105187 , -0.5074631 ],
#        [ 1.55168573, -0.26138796, -0.90861367, -1.0105187 ,  1.97058663]])

# %% [markdown]
# ### Model Creation Through GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

params_grid = {'criterion' : ['squared_error', 'friedman_mse', 'absolutr_error', 'poisson'],
               'splitter' : ['best', 'random'],
               'max_features' : ['sqrt', 'log2']}

grid = GridSearchCV(DecisionTreeRegressor(), params_grid, refit = True, verbose = 3, n_jobs= -1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 20 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'friedman_mse', 'absolute_error', 'squared_error'}. Got 'absolutr_error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'absolutr_error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'absolute_error', 'squared_error', 'friedman_mse', 'poisson'}. Got 'absolutr_error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'friedman_mse', 'squared_error', 'absolute_error'}. Got 'absolutr_error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'poisson', 'absolute_error', 'squared_error'}. Got 'absolutr_error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'squared_error', 'poisson', 'absolute_error'}. Got 'absolutr_error' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'squared_error', 'absolute_error', 'friedman_mse'}. Got 'absolutr_error' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.69554433 0.6630695  0.65715408 0.66277263 0.64000469 0.59759995
#  0.63407934 0.63745691        nan        nan        nan        nan
#  0.66417001 0.66304314 0.6922425  0.62693112]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolutr_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print the best parameter after tuning
result = grid.cv_results_

grid_predictions = grid.predict(indep)

from sklearn.metrics import r2_score
R2_Score = r2_score(dep, grid_predictions)

# print(grid.best_params_)
print("Best parameter of DT-Grid {}:",format(grid.best_params_),R2_Score)
# Out:
# Best parameter of DT-Grid {}: {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'} 0.998667156135576

# %% [markdown]
# ### GridSearchCV Table

# %%
Total = pd.DataFrame(result)
Total
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.015977      0.006512         0.006543        0.003624
# 1        0.013845      0.004673         0.007271        0.003128
# 2        0.008998      0.001507         0.005098        0.001239
# 3        0.007060      0.001531         0.004896        0.001467
# 4        0.008295      0.001625         0.003429        0.000465
# 5        0.007868      0.001109         0.004119        0.001517
# 6        0.008110      0.001272         0.003405        0.000489
# 7        0.006298      0.000685         0.004650        0.000808
# 8        0.001601      0.000491         0.000000        0.000000
# 9        0.001920      0.000647         0.000000        0.000000
# 10       0.001935      0.000342         0.000000        0.000000
# 11       0.001797      0.000599         0.000000        0.000000
# 12       0.009328      0.004174         0.005599        0.002325
# 13       0.013290      0.006321         0.006625        0.001692
# 14       0.011061      0.001775         0.006986        0.000790
# 15       0.006283      0.002271         0.004873        0.001760
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolutr_error               sqrt           best
# 9   absolutr_error               sqrt         random
# 10  absolutr_error               log2           best
# 11  absolutr_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.760577
# 1   {'criterion': 'squared_error', 'max_features':...           0.744929
# 2   {'criterion': 'squared_error', 'max_features':...           0.747787
# 3   {'criterion': 'squared_error', 'max_features':...           0.669627
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.619500
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.624107
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.719019
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.642745
# 8   {'criterion': 'absolutr_error', 'max_features'...                NaN
# 9   {'criterion': 'absolutr_error', 'max_features'...                NaN
# 10  {'criterion': 'absolutr_error', 'max_features'...                NaN
# 11  {'criterion': 'absolutr_error', 'max_features'...                NaN
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.709415
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.722768
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.704788
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.651238
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.664452           0.745094           0.678800
# 1            0.514777           0.690532           0.680922
# 2            0.651176           0.713718           0.620577
# 3            0.587848           0.731253           0.691731
# 4            0.449856           0.734836           0.692497
# 5            0.379097           0.686261           0.681565
# 6            0.683194           0.544680           0.750184
# 7            0.571150           0.708310           0.622479
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.554577           0.547908           0.728400
# 13           0.565411           0.678028           0.617399
# 14           0.637038           0.708590           0.733363
# 15           0.560156           0.660669           0.643404
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.628799         0.695544        0.049773                1
# 1            0.684188         0.663069        0.077731                4
# 2            0.552511         0.657154        0.068902                7
# 3            0.633403         0.662773        0.049095                6
# 4            0.703334         0.640005        0.102310                8
# 5            0.616969         0.597600        0.112900               12
# 6            0.473320         0.634079        0.106717               10
# 7            0.642601         0.637457        0.044035                9
# 8                 NaN              NaN             NaN               13
# 9                 NaN              NaN             NaN               13
# 10                NaN              NaN             NaN               13
# 11                NaN              NaN             NaN               13
# 12           0.780550         0.664170        0.095126                3
# 13           0.731610         0.663043        0.063417                5
# 14           0.677433         0.692242        0.032810                2
# 15           0.619189         0.626931        0.036109               11

# %% [markdown]
# ### Get the User Inputs

# %%
Age_input = float(input("Age : "))
Bmi_input = float(input("BMI : "))
Children_input = int(input("Children : "))
SEX_Male_input = int(input("Sex_Male 0 or 1 : "))
Smoker_YES_input = int(input("Smoker_YES 0 or 1 : "))
# Out:
# Age :  36
# BMI :  23.5
# Children :  2
# Sex_Male 0 or 1 :  0
# Smoker_YES 0 or 1 :  1

# %% [markdown]
# ### Predictions

# %%
Future_predictions = grid.predict([[Age_input,Bmi_input,Children_input,SEX_Male_input,Smoker_YES_input]])
print("Future predictions of Insurance :" , Future_predictions)
# Out:
# Future predictions of Insurance : [49577.6624]

# %% [markdown]
# ### Save the Model

# %%
import pickle
filename = "Final_DT-Grid_Model.sav"

# %%
pickle.dump(grid,open(filename,'wb'))

# %% [markdown]
# ### Load the Model

# %%
load_gridmodel = pickle.load(open("Final_DT-Grid_Model.sav",'rb'))
Final_result = load_gridmodel.predict([[Age_input,Bmi_input,Children_input,SEX_Male_input,Smoker_YES_input]])

# %%
Final_result
# Out:
# array([49577.6624])
